# %%
from pyspark.sql import DataFrame
from pyspark.sql import functions as F
from pathlib import Path

project_root = Path.cwd().parents[1]

workspace_csv_path = (
    project_root
    / "data"
    / "ingestion"
    / "inputDataTest.csv"
)

bronze_transactions_df = (
    spark.read
    .format("csv")
    .option("header", "true")
    .option("inferSchema", "false")
    .option("mode", "PERMISSIVE")
    .load(str(workspace_csv_path))
)
bronze_transactions_df = (
    bronze_transactions_df
    .withColumn("FILE_DATE", F.current_date())
    .withColumn("INGESTED_AT", F.current_timestamp())
)

bronze_transactions_df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").save(str(project_root / "data" / "bronze"))
